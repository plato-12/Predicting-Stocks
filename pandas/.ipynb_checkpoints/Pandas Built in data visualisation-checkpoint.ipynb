# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/Users/Arnav39/Desktop/capm_fama_french(FAC project)(2nd sem)/week_1/df1.csv")
df2 = pd.read_csv("/Users/Arnav39/Desktop/capm_fama_french(FAC project)(2nd sem)/week_1/df2.csv")
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("bmh")
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("dark_background")
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("fivethirtyeight")
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
x = range(1,6)
y = [1, 4, 6, 8, 4]
plt.style.use('seaborn')
plt.fill_between(x, y)
plt.show()

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.scatter(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='Pastel1_r')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a', y='b', gridsize=25, cmap='Oranges')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
